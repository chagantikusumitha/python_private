# %% [markdown]
# # Today's Agenda
# - Dictionary
# > ### What is Dictionary?
# > ### Different ways of creating Dictionary?
# > ### How to call Dictionary elements?
# > ### How to apply different Dictionary operations?
# > ### What are the built-in functions availble in Dictionary!
# > ### How it is different from the set?

# %% [markdown]
# **A Python dictionary is a data structure that stores key/value pairs. Each element of a Python dictionary is a key/value pair. The keys are like an index operator. In a list, the indexes are integers. In a dictionary, the key must be a hashable object. A dictionary cannot contain duplicate keys. Each key maps to one value. A key and its corresponding value form an item (or entry) stored in a dictionary. The data structure is a called a “dictionary” because it resembles a word dictionary, where the words are the keys and the words’ definitions are the values. A dictionary is also known as a map, which maps each key to a value. It enables fast retrieval, deletion, and updating of the value by using the key.**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Dictionaries are a collection in python which consists of key-value pairs
# - Dictionaries are unordered, indexable and mutable
# - Dictionaries are defined using `{}`
# - Dictionaries don't allow duplicate keys

# %% [markdown]
# # 1. Creating a Dictionary
# - You can create a dictionary by enclosing the items inside a pair of curly braces ({}). Each item consists of a key, followed by a colon, followed by a value. The items are separated by commas.

# %%
students = {"111-34-3434":"John", "132-56-6290":"Peter"}
students
# Out:
# {'111-34-3434': 'John', '132-56-6290': 'Peter'}

# %% [markdown]
# **You can create an empty dictionary by using the following syntax:**

# %%
students = {} # Create an empty dictionary
students
# Out:
# {}

# %% [markdown]
# **Note:Python uses curly braces for sets and dictionaries. The syntax {} denotes an empty dictionary.To create an empty set, use set()**

# %% [markdown]
# # 2. Adding, Modifying, and Retrieving Values

# %%
students = {"111":"Pradeep", "222":"Kumar"}
print(students)
# Out:
# {'111': 'Pradeep', '222': 'Kumar'}

# %%
students['111'] = 'Sandeep'

# %%
students
# Out:
# {'111': 'Sandeep', '222': 'Kumar'}

# %%
students['333'] = 'Raju'

# %%
students
# Out:
# {'111': 'Sandeep', '222': 'Kumar', '333': 'Raju'}

# %%
"name" : "Dhoni",
"age" : 39,
city
college
qualification
idno
branch
mobile

# %%
len(students)
# Out:
# 2

# %%
students['222']
# Out:
# 'Kumar'

# %%
students["444"] = "Anudeep" # Add a new item
print(students)
# Out:
# {'111': 'Sandeep', '222': 'Kumar', '333': 'Raju', '444': 'Anudeep'}

# %%
#Value overring
students["111"] = "Akhil"
students["111"]
# Out:
# 'Akhil'

# %%
students
# Out:
# {'111': 'Sandeep', '222': 'Kumar', '333': 'Raju', '444': 'Anudeep'}

# %%
students["555"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-c61d4c884915> in <module>
# ----> 1 students["555"]
#
# KeyError: '555'

# %% [markdown]
# ### get()
# - To prevent a KeyError exception, we can use the get() function on a dictionary. Then, if a value is not found for a given key, it returns nothing (and otherwise returns the value associated with that key).

# %%
students.get("555")

# %%
students.get("444") # dictionary.get(key)
# Out:
# 'Anudeep'

# %%
list(students.keys())
# Out:
# ['111', '222', '333', '444']

# %%
students['111']
# Out:
# 'Sandeep'

# %%
students.values()
# Out:
# dict_values(['Sandeep', 'Kumar', 'Raju', 'Anudeep'])

# %%
type(students.keys())
# Out:
# dict_keys

# %%
for i in list(students.keys()):
    print("for key "+i+' value is '+students[i])
# Out:
# for key 111 value is Sandeep
# for key 222 value is Kumar
# for key 333 value is Raju
# for key 444 value is Anudeep

# %%
list(students.items())
# Out:
# [('111', 'Sandeep'), ('222', 'Kumar'), ('333', 'Raju'), ('444', 'Anudeep')]

# %%
students['111']
# Out:
# 'Sandeep'

# %%
for i in list(students.items()):
    print("for key "+str(i[0])+" value is "+students[i[0]])
# Out:
# for key 111 value is Sandeep
# for key 222 value is Kumar
# for key 333 value is Raju
# for key 444 value is Anudeep

# %% [markdown]
# # 3. Getting all

# %% [markdown]
# ### key()

# %%
students.keys()
# Out:
# dict_keys(['111', '222', '333'])

# %% [markdown]
# ### values()

# %%
students.values()
# Out:
# dict_values(['Akhil', 'Kumar', 'Anudeep'])

# %% [markdown]
# ### items()

# %%
students.items()
# Out:
# dict_items([('111', 'Akhil'), ('222', 'Kumar'), ('333', 'Anudeep')])

# %%
tuple(students.items())
# Out:
# (('111', 'Akhil'), ('222', 'Kumar'), ('333', 'Anudeep'))

# %% [markdown]
# # 4. Common operations
# - in
# - not in
# - ==
# - !=

# %%
students = {"111-34-3434":"John", "132-56-6290":"Peter"}
len(students)
# Out:
# 2

# %%
"111-34-3434" in students
# Out:
# True

# %%
#Performing membership test
#This test is only valid for keys not values
numbers = {1:1,2:4,3:9,4:16,5:25,6:36}
#Since 1 is a key we get true for this
print( 1 in numbers)
# Out:
# True

# %%
"999-34-3434" not in students
# Out:
# True

# %%
d1 = {"red":41, "blue":3}
d2 = {"blue":3, "red":41}
d1 == d2  #d1 != d2
# Out:
# True

# %%
d1 = {"red":41, "blue":3}
d2 = {"blue":3, "red":41}
d1 != d2
# Out:
# False

# %% [markdown]
# **You cannot use the comparison operators (>, >=, <=, and <) to compare dictionaries because the items are not ordered.**

# %% [markdown]
# # 5.Removing values from a dictionary

# %%
employee = {
    'Name': 'Eswar',
    'ID': 'A01',
    'Blood group': 'A-',
    'Age': 50
}

# %%
employee
# Out:
# {'Name': 'Eswar', 'ID': 'A01', 'Blood group': 'A-', 'Age': 50}

# %%
employee
# Out:
# {'Name': 'Eswar', 'ID': 'A01', 'Blood group': 'A-', 'Age': 50}

# %% [markdown]
# ### pop()
# - remove the key-value pair
# - pop will remove any key-value pair

# %%
deleted_value = employee.pop('Age')
deleted_value
# Out:
# 50

# %%
employee
# Out:
# {'Name': 'Eswar', 'ID': 'A01', 'Blood group': 'A-'}

# %% [markdown]
# ### popitem()
# - to remove the last key-value pair

# %%
employee
# Out:
# {'Name': 'Eswar', 'ID': 'A01'}

# %%
employee.popitem()
# Out:
# ('Blood group', 'A-')

# %% [markdown]
# ### del
# - using `del` to remove ('Blood group','A-')

# %%
del employee['ID']
employee
# Out:
# {'Name': 'Eswar'}

# %% [markdown]
# # 6.Some dictionary methods

# %% [markdown]
# ### fromkeys()

# %%
# to make a dictionary from a set of keys and value
keys = ['A','B','C']
values = 10

di = dict.fromkeys(keys,values)
di
# Out:
# {'A': 10, 'B': 10, 'C': 10}

# %% [markdown]
# ### unpacking

# %%
fruit_prices = {'apple': 0.40, 'orange': 0.35}
vegetable_prices = {'pepper': 0.20, 'onion': 0.55}
# How to use the unpacking operator **
{**vegetable_prices, **fruit_prices}
# Out:
# {'pepper': 0.2, 'onion': 0.55, 'apple': 0.4, 'orange': 0.35}

# %% [markdown]
# ### 1. create a dictionary and count number of characters in each value
# ### 2.

# %%
for i in list(students.values()):
    print("for value "+i+" length is "+str(len(i)))
# Out:
# for value Sandeep length is 7
# for value Kumar length is 5
# for value Raju length is 4
# for value Anudeep length is 7

# %%
'111' in students.keys()
# Out:
# True

# %%
'Sandeep' not in students.values()
# Out:
# False

# %%
d = {'A':1, 'B':2, 'C': 1, 'D':5, 'E':2, 'F':7, 'G':8, 'H':9, 
     'I':7}
d
# Out:
# {'A': 1, 'B': 2, 'C': 4, 'D': 5, 'E': 6, 'F': 7, 'G': 8, 'H': 9, 'I': 10}

# %% [markdown]
# ### 1. Change the value of key 'E' to 25
# ### 2. include a new key and value pair(j,11) to dictionary
# ### 3. get the sum of all values

# %%
d['E'] = 25

# %%
d
# Out:
# {'A': 1, 'B': 2, 'C': 4, 'D': 5, 'E': 25, 'F': 7, 'G': 8, 'H': 9, 'I': 10}

# %%
d['j'] = 11
d
# Out:
# {'A': 1,
#  'B': 2,
#  'C': 4,
#  'D': 5,
#  'E': 25,
#  'F': 7,
#  'G': 8,
#  'H': 9,
#  'I': 10,
#  'j': 11}

# %%
sum = 0
for i in list(d.values()):
    sum = sum + i
print(sum)
# Out:
# 82

# %% [markdown]
# ### get the dictionary with unique values
