# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("tested.csv")
# df_loan=pd.read_csv("E:\\Innomatics\\data\\loandata.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# ### Save a Graph

# %%
sns.scatterplot(x=df_sales['Total_Cost'],y=df_sales["Total_Profit"])

plt.savefig("Cost_Profit.png")

# %% [markdown]
# ### Matplotlib Subplots
#
# You can use the subplot() method to add more than one plot in a figure.
#
# Syntax: plt.subplots(nrows, ncols, index)
#
# The three-integer arguments specify the number of rows and columns and the index of the subplot grid.
#
#
# Imagine we needed more than one plot on that canvas. Matplotlib allows us easily create multi-plots on the same figure using the .subplot() method. This .subplot() method takes in three parameters, namely:
#
# nrows: the number of rows the Figure should have.
# ncols: the number of columns the Figure should have.
# plot_number : which refers to a specific plot in the Figure.
#
#
# The figsize is a tuple of the width and height of the figure (in inches)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
fig, axs = plt.subplots(figsize=(15, 6),ncols=2)

sns.scatterplot(x=df["Age"],y=df['Fare'], ax=axs[1])#.set_title("Cost vs Profit")
sns.scatterplot(x=df['SibSp'],y=df["Parch"], ax=axs[0])#.set_title("Unit Price vs Unit Cost")
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='Parch'>

# %%
df_sales.columns

# %%
fig, axs = plt.subplots(figsize=(15, 10),nrows=2,ncols=2)

sns.boxplot(x=df_sales['Sales_Channel'],y=df_sales["Units_Sold"], ax=axs[0][0])
sns.boxplot(x=df_sales['Sales_Channel'],y=df_sales["Unit_SellingPrice"], ax=axs[0][1])
sns.boxplot(x=df_sales['Order_Priority'],y=df_sales["Units_Sold"], ax=axs[1][0])
sns.boxplot(x=df_sales['Sales_Channel'],y=df_sales["Total_Profit"], ax=axs[1][1])
# Out:
# <AxesSubplot:xlabel='Sales_Channel', ylabel='Total_Profit'>

# %% [markdown]
# ### Plot range
# Matplotlib allows us to set limits for our plots. We can easily configure the range of our plots using the set_ylim and set_xlim methods of the axis object, or axis(‘tight’) to automatically get “tightly fitted” axes ranges. For example, we can choose to show only plots between 0 to 1 of the x axis, and 0 to 5 of the y axis:

# %%
sns.scatterplot(df_loan["ApplicantIncome"],df_loan["LoanAmount"],hue=df_loan["Gender"])
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ApplicantIncome', ylabel='LoanAmount'>

# %%
sns.scatterplot(df_loan["ApplicantIncome"],df_loan["LoanAmount"],hue=df_loan["Gender"])
plt.xlim([0, 20000])
plt.ylim([0, 400])
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (0.0, 400.0)

# %% [markdown]
# %matplotlib notebook will lead to interactive plots embedded within the notebook
# %matplotlib inline will lead to static images of your plot embedded in the notebook

# %% [markdown]
# ### Multiple Graphs using for loop

# %%
cat_df = df.select_dtypes(exclude = 'number')

# %%
num_df = df.select_dtypes(include = 'number')

# %%
num_df.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare
# 0         0       3  34.5      0      0   7.8292
# 1         1       3  47.0      1      0   7.0000
# 2         0       2  62.0      0      0   9.6875
# 3         0       3  27.0      0      0   8.6625
# 4         1       3  22.0      1      1  12.2875

# %%
num_df.drop(["PassengerId"],inplace=True,axis= 1)
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
cat_df.head()
# Out:
#       Sex Cabin Embarked
# 0    male   NaN        Q
# 1  female   NaN        S
# 2    male   NaN        Q
# 3    male   NaN        S
# 4  female   NaN        S

# %%
cat_df.drop(['Name','Ticket'],inplace=True,axis= 1)
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
# category_columns=["Gender","Married","Dependents","Education","Self_Employed","Property_Area","Loan_Status"]
category_columns= df_loan.select_dtypes(include = 'object').columns.tolist()

# %%
cat_df.columns.tolist()
# Out:
# ['Sex', 'Cabin', 'Embarked']

# %%
for col in cat_df.columns.tolist():
        sns.countplot(x=col, data=df)
        plt.show()

# %%
for col in num_df.columns.tolist():
        sns.scatterplot(x=col, data=df)
        plt.show()

# %% [markdown]
# ### Catplot
#
#
# If you are working with data that involves any categorical variables.a data visualization library Seaborn encompasses several types of categorical plots into a single function: catplot()
#
# catplot() function includes 8 different types of categorical plots. The three most common plots: count plots, bar plots, and box plots.
#
#
# Categorical scatterplots with catplot
#
# stripplot() – with kind=”strip”
# swarmplot() – with kind=”swarm”
#
# Categorical distribution plots with catplot
#
# boxplot() – with kind=”box”
# violinplot() – with kind=”violin”
# boxenplot() – with kind=”boxen”
# Categorical estimate plots with catplot
# pointplot() – with kind=”point”
# barplot() – with kind=”bar”
# countplot() – with kind=”count”

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
sns.catplot(x="Pclass", y="Fare", data=df)

# %%
sns.catplot(x='Pclass', data=df, kind='count')

# %% [markdown]
# Changing the order of categories
#
# In our plot, the quality of the cut is from best to worst. But let’s reverse the order:

# %%
sns.catplot(x='Property_Area', data=df_loan, kind='count')

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
category_order = ['S','C','Q']

sns.catplot(x='Sex', data=df, kind='count',);

# %% [markdown]
# It is also important to keep in mind that a bar plot shows only the mean (or other estimator) value as default

# %%
df.groupby(['Embarked'])['Fare'].mean()
# Out:
# Embarked
# C    66.259765
# Q    10.957700
# S    28.230436
# Name: Fare, dtype: float64

# %%
sns.catplot(x='Embarked',
            y='Fare',
            data=df,
            kind='bar')

plt.xticks(rotation = 90)
plt.show()

# %%
sns.catplot(x='Embarked', y='Fare', data=df, kind='box')  
plt.xticks(rotation = 90)
plt.show()

# %%
sns.catplot(x='Embarked', y='Fare', data=df, kind='violin')  
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ### What is the difference between a bar chart and a histogram?
#
# The major difference is that a histogram is only used to plot the frequency of score occurrences in a continuous data set that has been divided into classes, called bins. Bar graph is a graphical representation of data that uses bars from numerical variable to compare different categories of categorical variable.
#
# Histogram used for displaying the frequency of occurrences and Bar Plots helps you to compare different categories of data.

# %%
df_sales.columns
# Out:
# Index(['Region', 'Country', 'Item_Type', 'Sales_Channel', 'Order_Priority',
#        'Order_Date', 'Order_ID', 'Ship_Date', 'Units_Sold',
#        'Unit_SellingPrice', 'Unit_MakingCost', 'Total_Revenue', 'Total_Cost',
#        'Total_Profit'],
#       dtype='object')

# %%
sns.distplot(df_sales["Total_Profit"],kde=True)
plt.title('Histogram of Total_Profit')
plt.show()
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df_sales["Total_Profit"].skew()
# Out:
# 1.263612349747273

# %% [markdown]
# Skewness values and interpretation
# There are many different approaches to the interpretation of the skewness values. A rule of thumb states that:
# Symmetric: Values between -0.5 to 0.5
# Moderated Skewed data: Values between -1 and -0.5 or between 0.5 and 1
# Highly Skewed data: Values less than -1 or greater than 1

# %%
loan_df = pd.read_excel('loandata.xlsx')

# %%
loan_df.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722    Male     Yes          0      Graduate            No
# 1  LP002502  Female     Yes          2  Not Graduate           NaN
# 2  LP002949  Female      No         3+      Graduate           NaN
# 3  LP002603  Female      No          0      Graduate            No
# 4  LP001644     NaN     Yes          0      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              150             1800.0       135.0             360.0
# 1              210             2917.0        98.0             360.0
# 2              416            41667.0       350.0             180.0
# 3              645             3683.0       113.0             480.0
# 4              674             5296.0       168.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0     Semiurban           Y
# ...

# %%
loan_df.shape
# Out:
# (614, 13)

# %%
loan_df.isna().sum()*100/len(loan_df)
# Out:
# Loan_ID              0.000000
# Gender               2.117264
# Married              0.488599
# Dependents           2.442997
# Education            0.000000
# Self_Employed        5.211726
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           3.583062
# Loan_Amount_Term     2.280130
# Credit_History       8.143322
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64
