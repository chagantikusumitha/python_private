# %%
import seaborn as sns

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('tested.csv')

# %% [markdown]
# # BAR CHART

# %%
sns.countplot(x='Embarked',data = df)
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %%
df_Cars = pd.read_csv('Cars_Data.csv')

# %%
sns.countplot(x='num-of-cylinders',data = df_Cars)
# Out:
# <AxesSubplot:xlabel='num-of-cylinders', ylabel='count'>

# %%
plt.figure(figsize = (10,5))
sns.countplot(x='num-of-cylinders',data = df_Cars)
plt.title('no. of cylinders')
plt.xlabel('Number of cylinders')
plt.ylabel('Frequency')
color = ['b','m','g','y']
plt.show()

# %% [markdown]
# # HISTOGRAM

# %%
sns.distplot(df_Cars['mileage'],kde = True,bins = [0,5,10,15,20,25,30])
plt.title('Histogram of mileage')
plt.show()

# %%
sns.distplot(df_Cars['price'],kde = False)
plt.title('Histogram of mileage')
plt.show()
# Out:
# C:\Users\kusumitha\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # BOX PLOT

# %%
df_Cars
# Out:
#     index        brand   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  mileage    price
# 0              four         111       21  13495.0
# ...

# %%
sns.boxplot(df_Cars['price'])
plt.show()
# Out:
# C:\Users\kusumitha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(df_Cars['mileage'])
plt.show()
# Out:
# C:\Users\kusumitha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # VIOLIN PLOT

# %%
plt.figure(figsize = (15,5))
sns.violinplot(df_Cars['price'])
plt.show()
# Out:
# C:\Users\kusumitha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # SATTER PLOT ( co-relation)

# %%
plt.scatter(df_Cars['price'],df_Cars['mileage'])

# %%
df_Cars.select_dtypes(include = 'number')
# Out:
#     index  wheel-base  length  horsepower  mileage    price
# 0       0        88.6   168.8         111       21  13495.0
# 1       1        88.6   168.8         111       21  16500.0
# 2       2        94.5   171.2         154       19  16500.0
# 3       3        99.8   176.6         102       24  13950.0
# 4       4        99.4   176.6         115       18  17450.0
# ..    ...         ...     ...         ...      ...      ...
# 56     81        97.3   171.7          85       27   7975.0
# 57     82        97.3   171.7          52       37   7995.0
# 58     86        97.3   171.7         100       26   9995.0
# 59     87       104.3   188.8         114       23  12940.0
# 60     88       104.3   188.8         114       23  13415.0
#
# [61 rows x 6 columns]

# %%
k = df_Cars.select_dtypes(include = 'number')

# %%
df_Cars.select_dtypes(exclude = 'number')
# Out:
#           brand   body-style engine-type num-of-cylinders
# 0   alfa-romero  convertible        dohc             four
# 1   alfa-romero  convertible        dohc             four
# 2   alfa-romero    hatchback        ohcv              six
# 3          audi        sedan         ohc             four
# 4          audi        sedan         ohc             five
# ..          ...          ...         ...              ...
# 56   volkswagen        sedan         ohc             four
# 57   volkswagen        sedan         ohc             four
# 58   volkswagen        sedan         ohc             four
# 59        volvo        sedan         ohc             four
# 60        volvo        wagon         ohc             four
#
# [61 rows x 4 columns]

# %%
h = df_Cars.select_dtypes(exclude = 'number')

# %%
#gives the coretation of each col
k.corr()
# Out:
#                index  wheel-base    length  horsepower   mileage     price
# index       1.000000    0.013401  0.004828   -0.093809  0.176037 -0.197470
# wheel-base  0.013401    1.000000  0.878381    0.463421 -0.547325  0.663085
# length      0.004828    0.878381  1.000000    0.668555 -0.788429  0.788465
# horsepower -0.093809    0.463421  0.668555    1.000000 -0.808804  0.901707
# mileage     0.176037   -0.547325 -0.788429   -0.808804  1.000000 -0.770217
# price      -0.197470    0.663085  0.788465    0.901707 -0.770217  1.000000

# %%
#correlations
sns.heatmap(k.corr(),annot = True)
plt.show()

# %% [markdown]
# # LINE CHART

# %%
sns.lineplot(x = 'price',y = 'mileage',data = df_Cars)
plt.show()

# %%
sns.lineplot(x = 'horsepower',y = 'mileage',data = df_Cars)
plt.show()

# %% [markdown]
# # BAR CHART

# %%
df_Cars.groupby('brand')['mileage'].mean()
# Out:
# brand
# alfa-romero      20.333333
# audi             20.000000
# bmw              19.000000
# chevrolet        41.000000
# dodge            31.000000
# honda            26.333333
# isuzu            33.333333
# jaguar           14.333333
# mazda            28.000000
# mercedes-benz    18.000000
# mitsubishi       29.500000
# nissan           31.400000
# porsche          17.000000
# toyota           28.714286
# volkswagen       31.750000
# volvo            23.000000
# Name: mileage, dtype: float64

# %%
sns.barplot(x = 'brand',y = 'mileage', data = df_Cars)
plt.xticks(rotation = 90)
plt.show()

# %%
sns.barplot(x = 'mileage',y = 'brand', data = df_Cars,orient = 'h')
plt.xticks(rotation = 90)
plt.show()

# %%
#barplot always takes groupby and takes mean if estimator is given as sum sum is plotted
sns.barplot(x = 'mileage',y = 'brand', data = df_Cars,orient = 'h',estimator = sum)
plt.xticks(rotation = 90)
plt.show()

# %%
df_Cars.columns
# Out:
# Index(['index', 'brand', 'body-style', 'wheel-base', 'length', 'engine-type',
#        'num-of-cylinders', 'horsepower', 'mileage', 'price'],
#       dtype='object')

# %%
crosstab = pd.crosstab(df_Cars['brand'],df_Cars['num-of-cylinders'])

# %%
crosstab
# Out:
# num-of-cylinders  eight  five  four  six  three  twelve  two
# brand
# alfa-romero           0     0     2    1      0       0    0
# audi                  0     3     1    0      0       0    0
# bmw                   0     0     2    4      0       0    0
# chevrolet             0     0     2    0      1       0    0
# dodge                 0     0     2    0      0       0    0
# honda                 0     0     3    0      0       0    0
# isuzu                 0     0     3    0      0       0    0
# jaguar                0     0     0    2      0       1    0
# mazda                 0     0     4    0      0       0    1
# mercedes-benz         2     2     0    0      0       0    0
# mitsubishi            0     0     4    0      0       0    0
# nissan                0     0     4    1      0       0    0
# porsche               1     0     0    2      0       0    0
# toyota                0     0     6    1      0       0    0
# ...

# %%
crosstab.plot(kind = 'bar',stacked = True)
plt.show()

# %%
crosstab.plot(kind = 'bar',stacked = False)
plt.show()

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [raw]
# SibSp col denotes no. of siblings u r travelling with.
# Embarked means, the place where they got into the ship
# Pclass is categorical col
# Parch parents

# %%
df['Pclass'].value_counts()
# Out:
# 3    218
# 1    107
# 2     93
# Name: Pclass, dtype: int64

# %%
df['Survived'].value_counts()
# Out:
# 0    266
# 1    152
# Name: Survived, dtype: int64

# %%
df['Sex'].value_counts()
# Out:
# male      266
# female    152
# Name: Sex, dtype: int64

# %%
crosstab = pd.crosstab(df_Cars['brand'],df_Cars['num-of-cylinders'])

# %%
h = df.select_dtypes(include = 'number')

# %%
h
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch      Fare
# 0            892         0       3  34.5      0      0    7.8292
# 1            893         1       3  47.0      1      0    7.0000
# 2            894         0       2  62.0      0      0    9.6875
# 3            895         0       3  27.0      0      0    8.6625
# 4            896         1       3  22.0      1      1   12.2875
# ..           ...       ...     ...   ...    ...    ...       ...
# 413         1305         0       3   NaN      0      0    8.0500
# 414         1306         1       1  39.0      0      0  108.9000
# 415         1307         0       3  38.5      0      0    7.2500
# 416         1308         0       3   NaN      0      0    8.0500
# 417         1309         0       3   NaN      1      1   22.3583
#
# [418 rows x 7 columns]

# %%
df1 = pd.read_csv("Cars_Data.csv")

# %%
df1
# Out:
#     index        brand   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  mileage    price
# 0              four         111       21  13495.0
# ...

# %%
df1.columns
# Out:
# Index(['index', 'brand', 'body-style', 'wheel-base', 'length', 'engine-type',
#        'num-of-cylinders', 'horsepower', 'mileage', 'price'],
#       dtype='object')

# %%
sns.scatterplot(df1['horsepower'],df1['mileage'],hue = df1['num-of-cylinders'])
plt.show()
#hue used to color based on categories and it takes only categorical
# Out:
# C:\Users\kusumitha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.scatterplot(df1['horsepower'],df1['mileage'],hue = df1['engine-type'])
plt.show()
# Out:
# C:\Users\kusumitha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(x = df1['body-style'],y = df1['price'],hue = df1['num-of-cylinders'])
plt.show()

# %% [markdown]
# # CAT PLOT

# %%
sns.catplot(x = 'Pclass',y = 'Fare',data = df)

# %%
sns.catplot(x = 'Pclass',data = df,kind = 'count')

# %%
catergory_order = [3,2,1]
sns.catplot(x = 'Pclass',data = df,kind = 'count', order = catergory_order)

# %%
sns.catplot(x = 'Embarked',data = df,kind = 'count')

# %%
O = ['S','C','Q']
sns.catplot(x = 'Embarked',data = df,kind = 'count', order = O)

# %%
sns.catplot(x = 'Sex',data = df,kind = 'count')

# %%
df.groupby(['Embarked'])['Fare'].mean()
# Out:
# Embarked
# C    66.259765
# Q    10.957700
# S    28.230436
# Name: Fare, dtype: float64

# %%
sns.catplot(x = 'Embarked',y = 'Fare',data = df,kind = 'bar')

# %%
sns.catplot(x = 'Embarked',y = 'Fare',data = df,kind = 'box')

# %%
sns.catplot(x = 'Embarked',y = 'Fare',data = df,kind = 'violin')

# %% [markdown]
# # SUB PLOTS

# %%
fig, axs = plt.subplots(figsize = (15,6),ncols = 2)
#figsize means size of fig and ncols denotes no.of cols we an give
sns.scatterplot(x = df['Age'],y = df['Fare'],ax = axs[0])
sns.scatterplot(x = df['SibSp'],y = df['Parch'],ax = axs[1])
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='Parch'>

# %%
fig, axs = plt.subplots(figsize = (15,6),ncols = 2)

sns.scatterplot(x = df['Age'],y = df['Fare'],ax = axs[1])
sns.scatterplot(x = df['SibSp'],y = df['Parch'],ax = axs[0])
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='Parch'>

# %%
fig, axs = plt.subplots(figsize = (6,15),nrows = 2)

sns.scatterplot(x = df['Age'],y = df['Fare'],ax = axs[1])
sns.scatterplot(x = df['SibSp'],y = df['Parch'],ax = axs[0])
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='Parch'>

# %%
fig, axs = plt.subplots(figsize = (15,10),nrows = 2,ncols = 2)

sns.scatterplot(x = df['Age'],y = df['Fare'],ax = axs[0][0])
sns.scatterplot(x = df['SibSp'],y = df['Parch'],ax = axs[0][1])
sns.scatterplot(x = df['Age'],y = df['Fare'],ax = axs[1][0])
sns.scatterplot(x = df['SibSp'],y = df['Parch'],ax = axs[1][1])
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='Parch'>

# %% [markdown]
# # SAVE  A GRAPH

# %%
sns.catplot(x = 'Sex',data = df,kind = 'count')

plt.savefig("Gender_Ratio.png")

# %% [raw]
# In this way we can save chart into system by using code

# %% [markdown]
# # Multiple Graphs using for loop

# %%
cat_df = df.select_dtypes(exclude = 'number')

# %%
num_df = df.select_dtypes(include = 'number')

# %%
cat_df.head()
# Out:
#                                            Name     Sex   Ticket Cabin  \
# 0                              Kelly, Mr. James    male   330911   NaN
# 1              Wilkes, Mrs. James (Ellen Needs)  female   363272   NaN
# 2                     Myles, Mr. Thomas Francis    male   240276   NaN
# 3                              Wirz, Mr. Albert    male   315154   NaN
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  3101298   NaN
#
#   Embarked
# 0        Q
# 1        S
# 2        Q
# 3        S
# 4        S

# %%
cat_df.drop(columns= ['Name','Ticket'],inplace = False)
# Out:
#         Sex Cabin Embarked
# 0      male   NaN        Q
# 1    female   NaN        S
# 2      male   NaN        Q
# 3      male   NaN        S
# 4    female   NaN        S
# ..      ...   ...      ...
# 413    male   NaN        S
# 414  female  C105        C
# 415    male   NaN        S
# 416    male   NaN        S
# 417    male   NaN        C
#
# [418 rows x 3 columns]

# %%
h = cat_df.drop(columns= ['Name','Ticket'])

# %%
h.columns.tolist()
# Out:
# ['Sex', 'Cabin', 'Embarked']

# %%
for col in h.columns.tolist():
    sns.countplot(x = col,data = h)
    plt.show()

# %%
num_df
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch      Fare
# 0            892         0       3  34.5      0      0    7.8292
# 1            893         1       3  47.0      1      0    7.0000
# 2            894         0       2  62.0      0      0    9.6875
# 3            895         0       3  27.0      0      0    8.6625
# 4            896         1       3  22.0      1      1   12.2875
# ..           ...       ...     ...   ...    ...    ...       ...
# 413         1305         0       3   NaN      0      0    8.0500
# 414         1306         1       1  39.0      0      0  108.9000
# 415         1307         0       3  38.5      0      0    7.2500
# 416         1308         0       3   NaN      0      0    8.0500
# 417         1309         0       3   NaN      1      1   22.3583
#
# [418 rows x 7 columns]

# %%
num_df.drop(columns= ['PassengerId'],inplace = False)
# Out:
#      Survived  Pclass   Age  SibSp  Parch      Fare
# 0           0       3  34.5      0      0    7.8292
# 1           1       3  47.0      1      0    7.0000
# 2           0       2  62.0      0      0    9.6875
# 3           0       3  27.0      0      0    8.6625
# 4           1       3  22.0      1      1   12.2875
# ..        ...     ...   ...    ...    ...       ...
# 413         0       3   NaN      0      0    8.0500
# 414         1       1  39.0      0      0  108.9000
# 415         0       3  38.5      0      0    7.2500
# 416         0       3   NaN      0      0    8.0500
# 417         0       3   NaN      1      1   22.3583
#
# [418 rows x 6 columns]

# %%
k = num_df.drop(columns= ['PassengerId'],inplace = False)

# %%
k.columns.tolist()
# Out:
# ['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
for col in k.columns.tolist():
    sns.countplot(x = col,data = k)
    plt.show()
