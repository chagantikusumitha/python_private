# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("Data.xlsx")

# %%
data
# Out:
#           banking marketing Unnamed: 1                    Unnamed: 2  \
# 0      customer id and age.        NaN  Customer salary and balance.
# 1                customerid        age                        salary
# 2                         1         58                        100000
# 3                         2         44                         60000
# 4                         3         33                        120000
# ...                     ...        ...                           ...
# 45208                 45207         51                         60000
# 45209                 45208         71                         55000
# 45210                 45209         72                         55000
# 45211                 45210         57                         20000
# 45212                 45211         37                        120000
#
#       Unnamed: 3                                         Unnamed: 4  \
# 0            NaN  Customer marital status and job with education...
# ...

# %% [markdown]
# converting row 2 as column names

# %% [raw]
# METHOD 1

# %%
cols = data.iloc[1]

# %%
cols.values
# Out:
# array(['customerid', 'age', 'salary', 'balance', 'marital', 'jobedu',
#        'targeted', 'default', 'housing', 'loan', 'contact', 'day',
#        'month', 'duration', 'campaign', 'pdays', 'previous', 'poutcome',
#        'response'], dtype=object)

# %%
pd.DataFrame(data.values[1:], columns=cols)
# Out:
# 1      customerid  age  salary  balance   marital                  jobedu  \
# 0      customerid  age  salary  balance   marital                  jobedu
# 1               1   58  100000     2143   married     management,tertiary
# 2               2   44   60000       29    single    technician,secondary
# 3               3   33  120000        2   married  entrepreneur,secondary
# 4               4   47   20000     1506   married     blue-collar,unknown
# ...           ...  ...     ...      ...       ...                     ...
# 45207       45207   51   60000      825   married     technician,tertiary
# 45208       45208   71   55000     1729  divorced         retired,primary
# 45209       45209   72   55000     5715   married       retired,secondary
# 45210       45210   57   20000      668   married   blue-collar,secondary
# 45211       45211   37  120000     2971   married  entrepreneur,secondary
#
# 1      targeted  default  housing  loan    contact  day      month  \
# ...

# %%
data.columns = cols

# %%
data
# Out:
# 1                customerid  age                        salary  balance  \
# 0      customer id and age.  NaN  Customer salary and balance.      NaN
# 1                customerid  age                        salary  balance
# 2                         1   58                        100000     2143
# 3                         2   44                         60000       29
# 4                         3   33                        120000        2
# ...                     ...  ...                           ...      ...
# 45208                 45207   51                         60000      825
# 45209                 45208   71                         55000     1729
# 45210                 45209   72                         55000     5715
# 45211                 45210   57                         20000      668
# 45212                 45211   37                        120000     2971
#
# 1                                                marital  \
# ...

# %%
data.iloc[2:,:]
# Out:
# 1     customerid age  salary balance   marital                  jobedu  \
# 2              1  58  100000    2143   married     management,tertiary
# 3              2  44   60000      29    single    technician,secondary
# 4              3  33  120000       2   married  entrepreneur,secondary
# 5              4  47   20000    1506   married     blue-collar,unknown
# 6              5  33       0       1    single         unknown,unknown
# ...          ...  ..     ...     ...       ...                     ...
# 45208      45207  51   60000     825   married     technician,tertiary
# 45209      45208  71   55000    1729  divorced         retired,primary
# 45210      45209  72   55000    5715   married       retired,secondary
# 45211      45210  57   20000     668   married   blue-collar,secondary
# 45212      45211  37  120000    2971   married  entrepreneur,secondary
#
# 1     targeted default housing loan    contact day      month  \
# ...

# %%
data.info()
#shd'nt use this as it convert all columns as objects
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45213 entries, 0 to 45212
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerid  45213 non-null  object
#  1   age         45192 non-null  object
#  2   salary      45213 non-null  object
#  3   balance     45212 non-null  object
#  4   marital     45213 non-null  object
#  5   jobedu      45212 non-null  object
#  6   targeted    45213 non-null  object
#  7   default     45212 non-null  object
#  8   housing     45213 non-null  object
#  9   loan        45212 non-null  object
#  10  contact     45213 non-null  object
#  11  day         45212 non-null  object
#  12  month       45163 non-null  object
#  13  duration    45213 non-null  object
#  14  campaign    45212 non-null  object
#  15  pdays       45212 non-null  object
#  16  previous    45212 non-null  object
#  17  poutcome    45213 non-null  object
#  18  response    45183 non-null  object
# ...

# %% [raw]
# METHOD 2

# %%
data = pd.read_excel("Data.xlsx",skiprows = 2)

# %%
data
# Out:
#        customerid   age  salary  balance   marital                  jobedu  \
# 0               1  58.0  100000     2143   married     management,tertiary
# 1               2  44.0   60000       29    single    technician,secondary
# 2               3  33.0  120000        2   married  entrepreneur,secondary
# 3               4  47.0   20000     1506   married     blue-collar,unknown
# 4               5  33.0       0        1    single         unknown,unknown
# ...           ...   ...     ...      ...       ...                     ...
# 45206       45207  51.0   60000      825   married     technician,tertiary
# 45207       45208  71.0   55000     1729  divorced         retired,primary
# 45208       45209  72.0   55000     5715   married       retired,secondary
# 45209       45210  57.0   20000      668   married   blue-collar,secondary
# 45210       45211  37.0  120000     2971   married  entrepreneur,secondary
#
#       targeted default housing loan    contact  day      month  \
# ...

# %%
data.info()
#by using this method column dtypes are remained same
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerid  45211 non-null  int64
#  1   age         45191 non-null  float64
#  2   salary      45211 non-null  object
#  3   balance     45211 non-null  int64
#  4   marital     45211 non-null  object
#  5   jobedu      45211 non-null  object
#  6   targeted    45211 non-null  object
#  7   default     45211 non-null  object
#  8   housing     45211 non-null  object
#  9   loan        45211 non-null  object
#  10  contact     45211 non-null  object
#  11  day         45211 non-null  int64
#  12  month       45161 non-null  object
#  13  duration    45211 non-null  object
#  14  campaign    45211 non-null  int64
#  15  pdays       45211 non-null  int64
#  16  previous    45211 non-null  int64
#  17  poutcome    45211 non-null  object
#  18  response    45181 non-null  object
# ...

# %% [markdown]
# In list we can take any data type
# whereas arrays takes only single dtypes

# %% [markdown]
# nan is a float value

# %%
data["jobedu"] = data["jobedu"].apply(lambda x:x.split(","))

# %%
data["jobedu"]
# Out:
# 0           [management, tertiary]
# 1          [technician, secondary]
# 2        [entrepreneur, secondary]
# 3           [blue-collar, unknown]
# 4               [unknown, unknown]
#                    ...
# 45206       [technician, tertiary]
# 45207           [retired, primary]
# 45208         [retired, secondary]
# 45209     [blue-collar, secondary]
# 45210    [entrepreneur, secondary]
# Name: jobedu, Length: 45211, dtype: object

# %%
data["job_role"] = data["jobedu"].apply(lambda x:x[1])

# %%
data["job_edu"] = data["jobedu"].apply(lambda x:x[0])

# %%
data
# Out:
#        customerid   age  salary  balance   marital                     jobedu  \
# 0               1  58.0  100000     2143   married     [management, tertiary]
# 1               2  44.0   60000       29    single    [technician, secondary]
# 2               3  33.0  120000        2   married  [entrepreneur, secondary]
# 3               4  47.0   20000     1506   married     [blue-collar, unknown]
# 4               5  33.0       0        1    single         [unknown, unknown]
# ...           ...   ...     ...      ...       ...                        ...
# 45206       45207  51.0   60000      825   married     [technician, tertiary]
# 45207       45208  71.0   55000     1729  divorced         [retired, primary]
# 45208       45209  72.0   55000     5715   married       [retired, secondary]
# 45209       45210  57.0   20000      668   married   [blue-collar, secondary]
# 45210       45211  37.0  120000     2971   married  [entrepreneur, secondary]
#
# ...

# %%
data.isna().sum()
# Out:
# customerid     0
# age           20
# salary         0
# balance        0
# marital        0
# jobedu         0
# targeted       0
# default        0
# housing        0
# loan           0
# contact        0
# day            0
# month         50
# duration       0
# campaign       0
# pdays          0
# previous       0
# poutcome       0
# response      30
# job_role       0
# job_edu        0
# dtype: int64

# %%
data["age"].fillna(data["age"].median(),inplace = True)

# %%
data["month"].value_counts(normalize = True)
#for percentage
# Out:
# may, 2017    0.304400
# jul, 2017    0.152521
# aug, 2017    0.138172
# jun, 2017    0.118133
# nov, 2017    0.087863
# apr, 2017    0.064901
# feb, 2017    0.058590
# jan, 2017    0.031044
# oct, 2017    0.016342
# sep, 2017    0.012754
# mar, 2017    0.010540
# dec, 2017    0.004739
# Name: month, dtype: float64

# %%
data.isna().sum()
# Out:
# customerid     0
# age            0
# salary         0
# balance        0
# marital        0
# jobedu         0
# targeted       0
# default        0
# housing        0
# loan           0
# contact        0
# day            0
# month         50
# duration       0
# campaign       0
# pdays          0
# previous       0
# poutcome       0
# response      30
# job_role       0
# job_edu        0
# dtype: int64

# %%
data["month"].mode()[0]
# Out:
# 'may, 2017'

# %%
data["month"].fillna(data["month"].mode()[0],inplace=True)

# %%
data.isna().sum()
# Out:
# customerid     0
# age            0
# salary         0
# balance        0
# marital        0
# jobedu         0
# targeted       0
# default        0
# housing        0
# loan           0
# contact        0
# day            0
# month          0
# duration       0
# campaign       0
# pdays          0
# previous       0
# poutcome       0
# response      30
# job_role       0
# job_edu        0
# dtype: int64

# %%
data.dropna(inplace= True)

# %%
data.isna().sum()
# Out:
# customerid    0
# age           0
# salary        0
# balance       0
# marital       0
# jobedu        0
# targeted      0
# default       0
# housing       0
# loan          0
# contact       0
# day           0
# month         0
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# response      0
# job_role      0
# job_edu       0
# dtype: int64

# %%
del data["jobedu"]

# %%
data
# Out:
#        customerid   age  salary  balance   marital targeted default housing  \
# 0               1  58.0  100000     2143   married      yes      no     yes
# 1               2  44.0   60000       29    single      yes      no     yes
# 2               3  33.0  120000        2   married      yes      no     yes
# 3               4  47.0   20000     1506   married       no      no     yes
# 4               5  33.0       0        1    single       no      no      no
# ...           ...   ...     ...      ...       ...      ...     ...     ...
# 45206       45207  51.0   60000      825   married      yes      no      no
# 45207       45208  71.0   55000     1729  divorced      yes      no      no
# 45208       45209  72.0   55000     5715   married      yes      no      no
# 45209       45210  57.0   20000      668   married      yes      no      no
# 45210       45211  37.0  120000     2971   married      yes      no      no
#
# ...

# %%
dur = []
for i in data["duration"]:
    if "sec" in i:
        dur.append(float(i.split()[0])/60)
    else:
        dur.append(i.split()[0])

# %%
data["duration"] = dur

# %%
data["duration"] = data["duration"].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45181 entries, 0 to 45210
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerid  45181 non-null  int64
#  1   age         45181 non-null  float64
#  2   salary      45181 non-null  object
#  3   balance     45181 non-null  int64
#  4   marital     45181 non-null  object
#  5   targeted    45181 non-null  object
#  6   default     45181 non-null  object
#  7   housing     45181 non-null  object
#  8   loan        45181 non-null  object
#  9   contact     45181 non-null  object
#  10  day         45181 non-null  int64
#  11  month       45181 non-null  object
#  12  duration    45181 non-null  float64
#  13  campaign    45181 non-null  int64
#  14  pdays       45181 non-null  int64
#  15  previous    45181 non-null  int64
#  16  poutcome    45181 non-null  object
#  17  response    45181 non-null  object
#  18  job_role    45181 non-null  object
# ...

# %%
data['duration'] = np.round(data['duration'],2)

# %%
data
# Out:
#        customerid   age  salary  balance   marital targeted default housing  \
# 0               1  58.0  100000     2143   married      yes      no     yes
# 1               2  44.0   60000       29    single      yes      no     yes
# 2               3  33.0  120000        2   married      yes      no     yes
# 3               4  47.0   20000     1506   married       no      no     yes
# 4               5  33.0       0        1    single       no      no      no
# ...           ...   ...     ...      ...       ...      ...     ...     ...
# 45206       45207  51.0   60000      825   married      yes      no      no
# 45207       45208  71.0   55000     1729  divorced      yes      no      no
# 45208       45209  72.0   55000     5715   married      yes      no      no
# 45209       45210  57.0   20000      668   married      yes      no      no
# 45210       45211  37.0  120000     2971   married      yes      no      no
#
# ...

# %% [markdown]
# # Uni Variate Analysis

# %%
del data['customerid']

# %%
num_cols = data.select_dtypes('number').columns
cat_cols = data.select_dtypes(exclude='number').columns

# %%
num_cols
# Out:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
cat_cols
# Out:
# Index(['salary', 'marital', 'targeted', 'default', 'housing', 'loan',
#        'contact', 'month', 'poutcome', 'response', 'job_role', 'job_edu'],
#       dtype='object')

# %%
pd.cut(data['duration'],[-0.1,5,10,20,30,100]).value_counts(normalize= True)*100
# Out:
# (-0.1, 5.0]      72.855846
# (5.0, 10.0]      18.764525
# (10.0, 20.0]      7.140170
# (20.0, 30.0]      1.002634
# (30.0, 100.0]     0.236825
# Name: duration, dtype: float64

# %%
data['duration'].describe()
# Out:
# count    45181.000000
# mean         4.302472
# std          4.292521
# min          0.000000
# 25%          1.720000
# 50%          3.000000
# 75%          5.320000
# max         81.970000
# Name: duration, dtype: float64

# %%
from ipywidgets import interact,interact_manual

# %%
@interact
def binns_analysis(col = num_cols):
    return pd.cut(data[col],4).value_counts(normalize= True)*100
# Out:
# interactive(children=(Dropdown(description='col', options=('age', 'balance', 'day', 'duration', 'campaign', 'p…

# %%
def boxplots(col):
    sns.boxplot(data[col])

# %%
boxplots('age')
# Out:
# C:\Users\kusumitha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
@interact_manual
def boxplots(col = num_cols):
    sns.boxplot(data[col])
# Out:
# interactive(children=(Dropdown(description='col', options=('age', 'balance', 'day', 'duration', 'campaign', 'p…

# %% [markdown]
# Numerical plots (univariate):
#
# - distplot
# - histogram
# - kdeplot
# - boxplot
#
# categorical plots:
#
# - countplot
# - pieplot
#
# two numericals:
#
# - scatterplot
# - regplot
# - relplot
# - heatmap
# - jointplot
#
# one numerical and one categorical:
#
# - barplot
# - boxplot
# - voilinplot
# - lineplot
#
# two categories:
#
# - do crosstab then plot barplot

# %%
@interact
def boxplots(col = num_cols,
            col1 = cat_cols):
    return data.groupby(col1)[col].agg({'min','mean','median','max'})
# Out:
# interactive(children=(Dropdown(description='col', options=('customerid', 'age', 'balance', 'day', 'campaign', …

# %%
@interact_manual
def boxplots(col = num_cols,
            col1 = cat_cols):
    sns.boxplot(data[col1],data[col])
# Out:
# interactive(children=(Dropdown(description='col', options=('customerid', 'age', 'balance', 'day', 'campaign', …
